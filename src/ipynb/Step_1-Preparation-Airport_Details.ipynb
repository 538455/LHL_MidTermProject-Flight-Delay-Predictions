# %% [markdown]
# # Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", 120)

# %%
airport_location = pd.read_csv("../../data/processed/flights_enrichment_airportLocation.csv", index_col=None)

# %%
airport_location
# Out:
#       iata_code local_code                                              name  \
# 0           LHR        NaN                           London Heathrow Airport
# 1           LAX        LAX                 Los Angeles International Airport
# 2           ORD        ORD              Chicago O'Hare International Airport
# 3           JFK        JFK              John F Kennedy International Airport
# 4           ATL        ATL  Hartsfield Jackson Atlanta International Airport
# ...         ...        ...                                               ...
# 35811       NaN        NaN                          Minas Municipal Airfield
# 35812       NaN        NaN                                Matahambre Airport
# 35813       NaN        NaN                              Minas De Oro Airport
# 35814       NaN        NaN                               Mário Spada Airport
# 35815       NaN        NaN                               Minas Novas Airport
#
# ...
